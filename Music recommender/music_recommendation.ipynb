# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import joblib

music_data = pd.read_csv('./datasets/music.csv')

# %%
X = music_data.drop(columns=['genre'])

y  = music_data['genre']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)            # allocating 20% of data for testing

# %%
model = DecisionTreeClassifier()

# model.fit(X_train,y_train)          # we teach the model on the train data, and then use test data

model.fit(X.values,y.values)

plot_tree(model, feature_names = ['age', 'gender'],
                    class_names = sorted(y.unique()),
                     filled = True)

# predictions = model.predict(X_test)

# score = accuracy_score(y_test,predictions)

# score
# Out:
# [Text(0.625, 0.875, 'age <= 30.5\ngini = 0.778\nsamples = 18\nvalue = [3, 6, 3, 3, 3]\nclass = Classical'),
#  Text(0.5, 0.625, 'age <= 25.5\ngini = 0.75\nsamples = 12\nvalue = [3, 0, 3, 3, 3]\nclass = Acoustic'),
#  Text(0.5625, 0.75, 'True  '),
#  Text(0.25, 0.375, 'gender <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0]\nclass = Dance'),
#  Text(0.125, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]\nclass = Dance'),
#  Text(0.375, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0]\nclass = HipHop'),
#  Text(0.75, 0.375, 'gender <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 0, 0, 0, 3]\nclass = Acoustic'),
#  Text(0.625, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]\nclass = Acoustic'),
#  Text(0.875, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]\nclass = Jazz'),
#  Text(0.75, 0.625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0, 0]\nclass = Classical'),
#  Text(0.6875, 0.75, '  False')]

# %% [markdown]
# ### Joblib - dumping a model

# %%
model = joblib.dump(model,'music-recommendation.joblib')

# %% [markdown]
# ### Joblib - loading a model

# %%
model = joblib.load('music-recommendation.joblib')

predictions = model.predict([[21,1]])

predictions
# Out:
# array(['HipHop'], dtype=object)
